# %% [markdown]
# # Laboratorio II: Diseño de un sistema de adquisición de datos. Parte I

# %% [markdown]
# En cuanto al diseño propuesto se elabora un circuito como el mostrado en el siguiente diagrama:

# %% [markdown]
# ![image.png](attachment:9e458297-1f15-44e5-8bc5-1b24460ecbe1.png)

# %% [markdown]
# En este se muestran las etapas que se trabajan, iniciando con la señal diferencial obtenida de la termocupla, pasando a la primer etapa de amplificación de ganancia en la que se va a aumentar el valor obtenido por la termocupla. Se realiza un amplificador como el de la siguiente imagen, con el cual logramos tomar los 10 mV obtenidos de la termocupla y amplificar el valor a 4 voltios.

# %% [markdown]
# ![Amp1.png](attachment:b791aff5-d93f-4317-b648-40a5762535e3.png)

# %% [markdown]
# A continuación, se pasa a la siguiente etapa en la que se hace uso del optoacoplador, tomando como volataje
# de entrada la señal de la termocupla. Después de esto se pasa a la etapa de amplificación la cual se regula por medio
# del potenciómetro R13.

# %% [markdown]
# ![Captura.PNG](attachment:7ea8cc2c-e34d-4878-9b4c-bbb96b318e47.PNG)

# %% [markdown]
# De la implementación de las etapas descritas anteriormente, se lograron las siguientes amplificaciones al variar el potenciómetro que define la ganancia.

# %% [markdown]
# ![image.png](attachment:6c2d744e-8c8d-4660-8eaf-c7addef18618.png)

# %% [markdown]
# ![image3.png](attachment:dedce3ba-3120-4277-80e8-bac470f3f7a6.png)![image4.png](attachment:74eda545-cfbb-4a75-8801-740c9d712798.png)![image2.png](attachment:ad8f90d3-71d3-4b20-8742-43079860b8ea.png)
